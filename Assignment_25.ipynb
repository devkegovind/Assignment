# %% [markdown]
# #**ASSIGNMENT NO.25**

# %% [markdown]
# **1) What is the difference between enclosing a list comprehension in square brackets and parentheses?**
# - The difference between the two kinds of expressions is that the List comprehension is enclosed in square brackets [] while the generator expression is enclosed in plain parenthesis().

# %%
l = [n*2 for n in range(1000)] # List comprehension
g = (n*2 for n in range(1000)) # generator expression

# %% [markdown]
# **Type**

# %%
print(type(l))
print(type(g))
# Out:
# <class 'list'>
# <class 'generator'>

# %% [markdown]
# **Size in memory**

# %%
import sys

print(sys.getsizeof(l))
print(sys.getsizeof(g))
# Out:
# 9032
# 128

# %% [markdown]
# **Access by Index**
# - We can access the elemnts of the `list`, but if we try to access the element of the `generator` we get a `TypeError`.

# %%
print(l[4])
print(g[4])
# Out:
# 8
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-6deaa69ab0fb> in <module>
#       1 print(l[4])
# ----> 2 print(g[4])
#
# TypeError: 'generator' object is not subscriptable

# %% [markdown]
# **2) What is the relationship between generators and iterators?**
# - **Iterators are the objects that use the next() method to get the next value of the sequence. A generator is a function that produces a yields a sequence of values using a yield statement.**
# - classes rae used to implement the iterators. Functions are used to implement the generator.

# %% [markdown]
# **3) What are the signs that a function is a generator function?**
# - **if a function contains at least one yield statement(it may contain other yield or return statements)**, it becomes a generator function. Both yield and return will return some value from a function.

# %% [markdown]
# **4) What is the purpose of a yield statement?**
# - The yield statement returns a generator object to the one who calls the function which contains yield, instead of simply returning a value.

# %% [markdown]
# **5) What is the relationship between map calls and list comprehensions? Make a
# between the two.**
# - **List comprehension is more concise and easier to read as compared to map.** List comprehension are used when a list of result is required as map only returns a map object and does not return any list. Map is faster in case of calling an already defined function (as no lambda is required).
