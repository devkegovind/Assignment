# %% [markdown]
# #**ASSIGNMENT NO.16**

# %% [markdown]
# **1. Create a list called years_list, starting with the year of your birth, and each year thereafter until the year of your fifth birthday. For example, if you were born in 1980. the list would be years_list = [1980, 1981, 1982, 1983, 1984, 1985].**

# %%
years_list = []
year_of_birth = 1987
for i in range(6):
  years_list.append(1987 + i)
print(f"years_list: {years_list}")
# Out:
# years_list: [1987, 1988, 1989, 1990, 1991, 1992]

# %% [markdown]
# **2. In which year in years_list was your third birthday? Remember, you were 0 years of age for your first year.**

# %%
print(f"Third_Birthday_year: {years_list[3]}")
# Out:
# Third_Birthday_year: 1990

# %% [markdown]
# **3.In the years list, which year were you the oldest?**

# %%
print(f"The oldest year is: {years_list[5]}")
# Out:
# The oldest year is: 1992

# %% [markdown]
# **4. Make a list called things with these three strings as elements: &quot;mozzarella&quot;, &quot;cinderella&quot;,
# &quot;salmonella&quot;.**

# %%
things = ["mozzarella", "cinderella", "salmonella"]
things
# Out:
# ['mozzarella', 'cinderella', 'salmonella']

# %% [markdown]
# **5. Capitalize the element in things that refers to a person and then print the list. Did it change the element in the list?**

# %%
for i in things:
  print(i.capitalize())
things
# Out:
# Mozzarella
# Cinderella
# Salmonella
# ['mozzarella', 'cinderella', 'salmonella']

# %% [markdown]
# **6. Make a surprise list with the elements &quot;Groucho,&quot; &quot;Chico,&quot; and &quot;Harpo.&quot;**

# %%
surprise_list = ["Groucho", "Chico", "Harpo"]
surprise_list
# Out:
# ['Groucho', 'Chico', 'Harpo']

# %% [markdown]
# **7. Lowercase the last element of the surprise list, reverse it, and then capitalize it.**

# %%
print(f"last element: {surprise_list[2].lower()}")
# Out:
# last element: harpo

# %%
print(f"last elment reverse: {surprise_list[2].lower()[::-1]}")
# Out:
# last elment reverse: oprah

# %%
print(f"last element reverse it and capitalize: {surprise_list[2].lower()[::-1].upper()}")
# Out:
# last element reverse it and capitalize: OPRAH

# %% [markdown]
# **8. Make an English-to-French dictionary called e2f and print it. Here are your starter words: dog is chien, cat is chat, and walrus is morse.**

# %%
e2f = {"dog":"chien", "cat":"chat", "walrus":"morse"}
e2f
# Out:
# {'dog': 'chien', 'cat': 'chat', 'walrus': 'morse'}

# %% [markdown]
# **9. Write the French word for walrus in your three-word dictionary e2f.**

# %%
print(f"French word for walrus is: {e2f['walrus']}")
# Out:
# French word for walrus is: morse

# %% [markdown]
# **10. Make a French-to-English dictionary called f2e from e2f. Use the items method.**

# %%
f2e = dict((key, value) for value, key in e2f.items())
f2e
# Out:
# {'chien': 'dog', 'chat': 'cat', 'morse': 'walrus'}

# %% [markdown]
# **11. Print the English version of the French word chien using f2e.**

# %%
f2e['chien']
# Out:
# 'dog'

# %% [markdown]
# **12. Make and print a set of English words from the keys in e2f.**

# %%
e2f.keys()
# Out:
# dict_keys(['dog', 'cat', 'walrus'])

# %% [markdown]
# **13. Make a multilevel dictionary called life. Use these strings for the topmost keys: &#39;animals&#39;, &#39;plants&#39;,and &#39;other&#39;. Make the &#39;animals&#39; key refer to another dictionary with the keys &#39;cats&#39;, &#39;octopi&#39;, and &#39;emus&#39;. Make the &#39;cats&#39; key refer to a list of strings with the values &#39;Henri&#39;, &#39;Grumpy&#39;, and &#39;Lucy&#39;.Make all the other keys refer to empty dictionaries.**

# %%
life = {"animals" :{"cats" : ["Henri", "Grumpy", "Lucy"] , "octopi": "", "emus" : ""}, "plants": "", "other": ""}
life
# Out:
# {'animals': {'cats': ['Henri', 'Grumpy', 'Lucy'], 'octopi': '', 'emus': ''},
#  'plants': '',
#  'other': ''}

# %% [markdown]
# **14. Print the top-level keys of life.**

# %%
life.keys()
# Out:
# dict_keys(['animals', 'plants', 'other'])

# %% [markdown]
# **15. Print the keys for life[&#39;animals&#39;].**

# %%
life['animals'].keys()
# Out:
# dict_keys(['cats', 'octopi', 'emus'])

# %% [markdown]
# **16. Print the values for life[&#39;animals&#39;][&#39;cats&#39;**]

# %%
life['animals']['cats']
# Out:
# ['Henri', 'Grumpy', 'Lucy']
