# %% [markdown]
# #**ASSIGNMENT_4**

# %% [markdown]
# **1. What exactly is []?**
# - It is empty list value, which is a list value that contains no items.

# %% [markdown]
# **2. In a list of values stored in a variable called spam, how would you assign the value &#39;hello&#39; as the
# third value? (Assume [2, 4, 6, 8, 10] are in spam.)
# Let&#39;s pretend the spam includes the list [&#39;a&#39;, &#39;b&#39;, &#39;c&#39;, &#39;d&#39;] for the next three queries.**

# %%
spam = [2,4,6,8,10]
spam[2] = 'hello'

# %%
spam
# Out:
# [2, 4, 'hello', 8, 10]

# %% [markdown]
# **3. What is the value of spam[int(int(&#39;3&#39; * 2) / 11)]?**
# - It gives the 'd' value from spam list.
# - Note that '3'*2 is the string '33', which is passed to int() before being divided by 11. This eventually evaluates to 3.

# %%
spam = ['a','b','c','d']
spam[int(int('3'*2)//11)]
# Out:
# 'd'

# %% [markdown]
# **4. What is the value of spam[-1]?**
# - Negative indexes count from the end.
# - It gives last element i.e. 'd' value.

# %%
spam[-1]
# Out:
# 'd'

# %% [markdown]
# **5. What is the value of spam[:2]?
# Let&#39;s pretend bacon has the list [3.14, &#39;cat,&#39; 11, &#39;cat,&#39; True] for the next three questions.**
# - ['a', 'b'] is the value of spam [:2].

# %%
spam[:2]
# Out:
# ['a', 'b']

# %% [markdown]
# **6. What is the value of bacon.index(&#39;cat&#39;)?**
# - One is the value of bacon.index('cat').

# %%
bacon = [3.14, 'cat', 11, 'cat', True]
bacon.index('cat')
# Out:
# 1

# %% [markdown]
# **7. How does bacon.append(99) change the look of the list value in bacon?**
# - bacon = [3.14, 'cat', 11, 'cat', True, 99]

# %%
bacon.append(99)
bacon
# Out:
# [3.14, 'cat', 11, 'cat', True, 99]

# %% [markdown]
# **8. How does bacon.remove(&#39;cat&#39;) change the look of the list in bacon?**
# - bacon = [3.14, 11, 'cat', True, 99]

# %%
bacon.remove('cat')
bacon
# Out:
# [3.14, 11, 'cat', True, 99]

# %% [markdown]
# **9. What are the list concatenation and list replication operators?**
# - The operator for list concatenation is +, while the operator for replication is *.
# - This is the same as for string.

# %% [markdown]
# **10. What is difference between the list methods append() and insert()?**
# - While append() method will add values only to the end of a list, insert() method can add them anywhere in the list.

# %% [markdown]
# **11. What are the two methods for removing items from a list?**
# - The del() and the remove() list method are two ways to removing items from a list.

# %% [markdown]
# **12. Describe how list values and string values are identical.**
# - The similarity between Lists and Strings in python is that both are sequences.
# - Lists are mutable but string are immutable.
# - Elements of a list can be of different types whereas a string only contains characters that are all of string type.

# %% [markdown]
# **13. What&#39;s the difference between tuples and lists?**
# - Lists are mutable; they can have values added, removed or changed.
# - Tuples are immutable; they cannot be changed at all.
# - Also, tuples are written using parenthesis,(and), while lists are use the square brackets,[ and ].

# %% [markdown]
# **14. How do you type a tuple value that only contains the integer 42?**
# - (42,) (The trailing comma is mandatory.).

# %% [markdown]
# **15. How do you get a list value&#39;s tuple form? How do you get a tuple value&#39;s list form?**
# - The tuple() and list() functions, respectively.

# %% [markdown]
# **16. Variables that &quot;contain&quot; list values are not necessarily lists themselves. Instead, what do they contain?**
# - They contain references to list values.

# %% [markdown]
# **17. How do you distinguish between copy.copy() and copy.deepcopy()?**
# - The copy.copy() function will do a shallow copy of a list while the copy.deepcopy() function will do a deep copy of a list.
# - In shallow copy, a copy of the original object is stored and only the reference address is finally copied.
# - In Deep copy, the copy of the original object and the repetitive copies both are stored.
