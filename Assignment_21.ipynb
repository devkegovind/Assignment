# %% [markdown]
# #**ASSIGNMENT NO.21**

# %% [markdown]
# **1. Add the current date to the text file today.txt as a string.**

# %%
# Creating Empty txt file


with open('today.txt', 'w') as file:
  pass
print("Emty File Created Successfully")



# importing datetime module
import datetime

# datetime.datetime().now() to get
# current date as filename
today = datetime.datetime.now()
today = str(today)

f = open('today.txt', "w")
f.write(today)
f.close()
# Out:
# Emty File Created Successfully

# %% [markdown]
# **2. Read the text file today.txt into the string today_string**

# %%
# open text file in read mode
today_string = open('today.txt', "r")

# read whole file to a string
data = today_string.read()

# close the file
today_string.close()

print(data)
# Out:
# 2022-10-31 05:16:32.233801

# %% [markdown]
# **3. Parse the date from today_string.**

# %%
from datetime import datetime

today_string = '2022-10-31 05:16:32'

today_string_obj = datetime.strptime(today_string, '%Y-%m-%d %H:%M:%S')

print("The type of the date is now", type(today_string_obj))

print("The date is:", today_string_obj)
# Out:
# The type of the date is now <class 'datetime.datetime'>
# The date is: 2022-10-31 05:16:32

# %% [markdown]
# **4. List the files in your current directory**

# %%
# import OS module
import os

# get the list of all files and directories
for x in os.listdir():
  print(x)
# Out:
# .config
# .ipynb_checkpoints
# today.txt
# sample_data

# %% [markdown]
# **5. Create a list of all of the files in your parent directory (minimum five files should be available)**

# %% [markdown]
# **6. Use multiprocessing to create three separate processes. Make each one wait a random number of
# seconds between one and five, print the current time, and then exit.**

# %%
# !pip install zoo
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for zoo: filename=zoo-0.1a0-py3-none-any.whl size=1233 sha256=4e34ad8de4cc27dfd7c4a87f1b1aab7347714e3a883e03b433b7fd27f545790f
#   Stored in directory: /root/.cache/pip/wheels/50/de/50/b3204ff1a490e7ed719119a6985d811fa5b5303f609aa7b163
# Successfully built zoo
# ...

# %%
# !pip install
# Out:
# ERROR: You must give at least one requirement to install (see "pip help install")

# %%
import zoo
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-33-0e1403c2ee87> in <module>
# ----> 1 import zoo
#
# ModuleNotFoundError: No module named 'zoo'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import multiprocessing, time, datetime


def process1():
  t1 = random.randint(1,5)
  print("Waiting for " + str(t1)+" seconds")
  time.sleep(t1)
  print(datetime.datetime.now())


start = time.time()
process1 = zoo.process1()
process2 = zoo.process1()
process3 = zoo.process1()

print(datetime.datetime.now())

if __name__=="__main__":

  p1 = multiprocessing.Process(target = process1)
  p2 = multiprocessing.Process(target = process2)
  p3 = multiprocessing.Process(target = process3)

  p1.start()
  p2.start()
  p3.start()


end = time.time()

print("It takes " +str(end-start)+" seconnds")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-30-0014b8f8fc09> in <module>
#       1 import multiprocessing, time, datetime
# ----> 2 import zoo
#       3
#       4 def process1():
#       5   t1 = random.randint(1,5)
#
# ModuleNotFoundError: No module named 'zoo'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# **7. Create a date object of your day of birth.**

# %%
from datetime import datetime

birthday = input("Enter your date of birth: ")

bday = datetime.strptime(birthday, '%d/%m/%Y')

print(f'Day: {bday.day}')
print(f'Month: {bday.month}')
print(f'Year:{bday.year}')
# Out:
# Enter your date of birth: 06/07/1987
# Day: 6
# Month: 7
# Year:1987

# %% [markdown]
# **8. What day of the week was your day of birth?**

# %%
import datetime
import calendar

def findDay(date):
  born = datetime.datetime.strptime(date, '%d %m %Y').weekday()
  return (calendar.day_name[born])


date = '06 07 1987'
print(findDay(date))
# Out:
# Monday

# %% [markdown]
# **9. When will you be (or when were you) 10,000 days old?**

# %%
import datetime

start_date = datetime.datetime(year = 1987, month = 7, day = 6)

end_date = start_date + datetime.timedelta(days = 10000)

print(end_date.date())
# Out:
# 2014-11-21
