# %% [markdown]
# #**ASSIGNMENT_6**

# %% [markdown]
# **1. What are escape characters, and how do you use them?**
# - In python strings, the backslash "\\" is a special character, also called the 'escape' character.
# - It is used in representing certain whitespace characters.
# - "\t" is a tab, "\n" is a newline and "\r" carriage return.

# %% [markdown]
# **2. What do the escape characters n and t stand for?**
# - character n stand for a newline.
# - character t stand is a tab.

# %% [markdown]
# **3. What is the way to include backslash characters in a string?**
# - Python backslash (\\) to escape other special characters used as a part of special sequence such as \t and \n.
# - Use the python backslash (\\) to escape other special character in as string.
# - F-string cannot contains the backslash a part of expression inside the curly braces {}.

# %% [markdown]
# **4. The string &quot;Howl&#39;s Moving Castle&quot; is a correct value. Why isn&#39;t the single quote character in the word Howl&#39;s not escaped a problem?**
# - The single quote in Howl's is fine because you've used double quotes to mark the beginning and end of the string.

# %%
s = 'Howl's 'Moving Castle'
s
# Out:
#   File "<ipython-input-1-b3f28a74f631>", line 1
#     s = 'Howl's 'Moving Castle'
#               ^
# SyntaxError: invalid syntax

# %%
s = "Howl's Moving Castle"
s
# Out:
# "Howl's Moving Castle"

# %% [markdown]
# **5. How do you write a string of newlines if you don&#39;t want to use the n character?**
# - It is the simplest method to let a long string split into different lines. You will need to enclose it with a pair of triple quotes, one at the start and second in the end.

# %% [markdown]
# **6. What are the values of the given expressions?
# &#39;Hello, world!&#39;[1]
# &#39;Hello, world!&#39;[0:5]
# &#39;Hello, world!&#39;[:5]
# &#39;Hello, world!&#39;[3:]**
# - Hello, world!&#39;[1]---'e'
# - &#39;Hello, world!&#39;[0:5]---'Hello'
# - &#39;Hello, world!&#39;[:5]---'Hello'
# - &#39;Hello, world!&#39;[3:]---'lo, world!

# %% [markdown]
# **7. What are the values of the following expressions?
# &#39;Hello&#39;.upper()
# &#39;Hello&#39;.upper().isupper()
# &#39;Hello&#39;.upper().lower()**
# - 'Hello'.upper() --- 'HELLO'
# - 'Hello'.upper().isupper()--- True
# - 'Hello'.upper().lower() --- 'hello'

# %% [markdown]
# **8. What are the values of the following expressions?
# &#39;Remember, remember, the fifth of July.&#39;.split()
# &#39;-&#39;.join(&#39;There can only one.&#39;.split())**
# -

# %% [markdown]
# **9. What are the methods for right-justifying, left-justifying, and centering a string?**
# - The method for right-justifying string is str.rjust(s, width[, fillchar]).
# - The method for left-justifying string is str.ljust(s, width[, fillchar]).
# - The method is centering string is str.center(s, width[, fillchar]).

# %% [markdown]
# **10. What is the best way to remove whitespace characters from the start or end?**
# - The trim() method returns a string with whitespace characters removed from the start and end of the string.
