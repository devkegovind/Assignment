# %% [markdown]
# #**ASSIGNMENT NO.22**

# %% [markdown]
# **1. What is the result of the code, and explain?**
#
# &gt;&gt;&gt; X = &#39;iNeuron&#39;
#
# &gt;&gt;&gt; def func():
#
# print(X)
#
# &gt;&gt;&gt; func()

# %%
X = 'iNeuron'

def func():
  print(X)

func()
# Out:
# iNeuron

# %% [markdown]
# **2. What is the result of the code, and explain?**
#
# &gt;&gt;&gt; X = &#39;iNeuron&#39;
# &gt;&gt;&gt; def func():
# X = &#39;NI!&#39;
#
# &gt;&gt;&gt; func()
# &gt;&gt;&gt; print(X)

# %%
X = 'iNeuron'

def func():
  X = 'NI!'

func()
print(X)
# Out:
# iNeuron

# %% [markdown]
# **3. What does this code print, and why?**
#
# &gt;&gt;&gt; X = &#39;iNeuron&#39;
# &gt;&gt;&gt; def func():
# X = &#39;NI&#39;
# print(X)
#
# &gt;&gt;&gt; func()
# &gt;&gt;&gt; print(X)

# %%
X = 'iNeuron'

def func():
  X = "NI"
  print(X)

func()
print(X)
# Out:
# NI
# iNeuron

# %% [markdown]
# **4. What output does this code produce? Why?**
#
# &gt;&gt;&gt; X = &#39;iNeuron&#39;
# &gt;&gt;&gt; def func():
# global X
# X = &#39;NI&#39;
#
# &gt;&gt;&gt; func()
#
# &gt;&gt;&gt; print(X)

# %%
X = "iNeuron"

def func():
  global X  = 'NI'

func()
print(X)
# Out:
#   File "<ipython-input-7-7880463acf30>", line 4
#     global X  = 'NI'
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# **5. What about this code—what’s the output, and why?**
#
# &gt;&gt;&gt; X = &#39;iNeuron&#39;
#
# &gt;&gt;&gt; def func():
#
# X = &#39;NI&#39;
#
# def nested():
#
# print(X)
#
# nested()
#
#
# &gt;&gt;&gt; func()
#
# &gt;&gt;&gt; X

# %%
X = 'iNeuron'

def func():
  X = "NI"

  def nested():
    print(X)
    nested()

func()
X
# Out:
# 'iNeuron'

# %% [markdown]
# **6. How about this code: what is its output in Python 3, and explain?**
#
# &gt;&gt;&gt; def func():
#
# X = &#39;NI&#39;
#
# def nested():
#
# nonlocal X
#
# X = &#39;Spam&#39;
#
# nested()
#
# print(X)
#
# &gt;&gt;&gt; func()

# %%
def func():
  X = "NI"

  def nested():
    nonlocal X
    X = 'Spam'
    nested()
    print(X)


func()
