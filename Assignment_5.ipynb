# %% [markdown]
# #**ASSIGNMENT_5**

# %% [markdown]
# **1. What does an empty dictionary&#39;s code look like?**
# - To create an empty dictionary, first create a variable name which will be the name of the dictionary. Then, assign the variable to an empty set of curly braces,{}. Another way to creating an empty dictionary is to use  the dict() function without passing any arguments.
#
# a = {}
#
# a = dict()

# %% [markdown]
# **2. What is the value of a dictionary value with the key &#39;foo&#39; and the value 42?**
# - tmp = {'foo' : 42}

# %% [markdown]
# **3. What is the most significant distinction between a dictionary and a list?**
# - A list is an ordered sequence of objects, whereas dictionaries are unordered sets.
# - Howeve, the main difference is that items in dictionaries are accessed via keys and not via their position.

# %% [markdown]
# **4. What happens if you try to access spam[&#39;foo&#39;] if spam is {&#39;bar&#39;: 100}?**
# - It will give KeyError: 'foo'.

# %% [markdown]
# **5. If a dictionary is stored in spam, what is the difference between the expressions &#39;cat&#39; in spam and &#39;cat&#39; in spam.keys()?**
# - There is no difference, the expression 'cat' in spam checks whether 'cat' is a key in spam.

# %% [markdown]
# **6. If a dictionary is stored in spam, what is the difference between the expressions &#39;cat&#39; in spam and
# &#39;cat&#39; in spam.values()?**
# - 'cat' in spam checks whether 'cat' exists as a key in spam. 'cat' in spam.values() check whether 'cat' in spam.

# %% [markdown]
# **7. What is a shortcut for the following code?
# if &#39;color&#39; not in spam:
# spam[&#39;color&#39;] = &#39;black&#39;**
# - spam.setdefault('color', 'black')

# %% [markdown]
# **8. How do you &quot;pretty print&quot; dictionary values using which module and function?**
# - The module is pprint.
# - The function are pprint.pprint() and pprint.pformat().

# %%
import pprint

# %%
pprint.pprint("com")
# Out:
# 'com'

# %%
pprint.pformat("com")
# Out:
# "'com'"
